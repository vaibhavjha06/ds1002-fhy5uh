# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhavjha06/ds1002-fhy5uh/blob/main/homework/week-12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt

plt.pie(slices, labels = ['US', 'UK', 'MX', 'CA', 'JP'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7c236bc850c0>,
#   <matplotlib.patches.Wedge at 0x7c236bc84fd0>,
#   <matplotlib.patches.Wedge at 0x7c236bc85990>,
#   <matplotlib.patches.Wedge at 0x7c236bc85e10>,
#   <matplotlib.patches.Wedge at 0x7c236bc86290>],
#  [Text(0.9349011005821531, 0.5796205069959818, 'US'),
#   Text(-0.21125715497921718, 1.079523234798625, 'UK'),
#   Text(-0.9728300181275684, 0.5134216160524556, 'MX'),
#   Text(-0.6116935558191647, -0.9142379306117783, 'CA'),
#   Text(0.9828146941303805, -0.49403975245055637, 'JP')])

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
import seaborn as sns

sns.histplot(n)
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
plt.scatter(x,y)
z = np.polyfit(x, y, 1)
p = np.poly1d(z)

plt.plot(x,p(x))
